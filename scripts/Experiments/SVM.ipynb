# %% [markdown]
# ### Import Functions

# %%
from ipynb.fs.full.utilities import *
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction import DictVectorizer
from sklearn import preprocessing
import pickle
from sklearn.metrics import classification_report

# %% [markdown]
# ### Data Prep

# %%
X_train_60 = load_json('../../data/Train_60_X.json')
y_train_60 = load_json('../../data/Train_60_y.json')
X_dev = load_json('../../data/Dev_X.json')
y_dev = load_json('../../data/Dev_y.json')

# %%
verify_prepped_data(X_train_60, y_train_60)

# %%
verify_prepped_data(X_dev, y_dev)

# %%
X_train_60_flat = [word for sentence in X_train_60 for word in sentence]
y_train_60_flat = [label for sentence in y_train_60 for label in sentence]
X_dev_flat = [word for sentence in X_dev for word in sentence]
y_dev_flat = [label for sentence in y_dev for label in sentence]

# %%
len(X_train_60_flat) == len(y_train_60_flat)
# Out:
# True

# %%
len(X_dev_flat) == len(y_dev_flat)
# Out:
# True

# %%
X_train_60[0]
# Out:
# [{'word': '^',
#   'sent_len': 6,
#   'upos': 'PART',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Te',
#   'BOS': True,
#   'next_word': 'нека',
#   'next_word_upos': 'PART',
#   'next_word_xpos_type': 'Tv',
#   'word_after_next_word': 'не',
#   'word_after_next_word_upos': 'PART',
#   'word_after_next_word_xpos_type': 'Tn',
#   'contains_publicistic_word': False},
#  {'word': 'нека',
#   'sent_len': 6,
#   'upos': 'PART',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Tv',
#   'prev_word': '^',
#   'prev_word_upos': 'PART',
#   'prev_word_xpos_type': 'Te',
#   'next_word': 'не',
#   'next_word_upos': 'PART',
#   'next_word_xpos_type': 'Tn',
#   'word_after_next_word': 'кажат',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-p',
#   'contains_publicistic_word': False},
#  {'word': 'не',
#   'sent_len': 6,
#   'upos': 'PART',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Tn',
#   'prev_word': 'нека',
#   'prev_word_upos': 'PART',
#   'prev_word_xpos_type': 'Tv',
#   'word_before_prev_word': '^',
#   'word_before_prev_word_upos': 'PART',
#   'word_before_prev_word_xpos_type': 'Te',
#   'next_word': 'кажат',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-p',
#   'word_after_next_word': 'погълнахме',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-p',
#   'contains_publicistic_word': False},
#  {'word': 'кажат',
#   'sent_len': 6,
#   'upos': 'VERB',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-p',
#   'prev_word': 'не',
#   'prev_word_upos': 'PART',
#   'prev_word_xpos_type': 'Tn',
#   'word_before_prev_word': 'нека',
#   'word_before_prev_word_upos': 'PART',
#   'word_before_prev_word_xpos_type': 'Tv',
#   'next_word': 'погълнахме',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-p',
#   'word_after_next_word': 'го',
#   'word_after_next_word_upos': 'PRON',
#   'word_after_next_word_xpos_type': 'Pp',
#   'word_after_next_word_xpos_gender_number_article': 'ms',
#   'word_after_next_word_xpos_ref_type': 'e',
#   'contains_publicistic_word': False},
#  {'word': 'погълнахме',
#   'sent_len': 6,
#   'upos': 'VERB',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-p',
#   'prev_word': 'кажат',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-p',
#   'word_before_prev_word': 'не',
#   'word_before_prev_word_upos': 'PART',
#   'word_before_prev_word_xpos_type': 'Tn',
#   'next_word': 'го',
#   'next_word_upos': 'PRON',
#   'next_word_xpos_type': 'Pp',
#   'next_word_xpos_gender_number_article': 'ms',
#   'next_word_xpos_ref_type': 'e',
#   'contains_publicistic_word': False},
#  {'word': 'го',
#   'sent_len': 6,
#   'upos': 'PRON',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Pp',
#   'word_xpos_gender_number_article': 'ms',
#   'word_xpos_ref_type': 'e',
#   'prev_word': 'погълнахме',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-p',
#   'word_before_prev_word': 'кажат',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-p',
#   'EOS': True,
#   'contains_publicistic_word': False}]

# %%
X_dev[0]
# Out:
# [{'word': '^',
#   'sent_len': 42,
#   'upos': 'CCONJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'punct',
#   'BOS': True,
#   'next_word': 'но',
#   'next_word_upos': 'CCONJ',
#   'next_word_xpos_type': 'Cc',
#   'word_after_next_word': 'синовете',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'mpd',
#   'contains_publicistic_word': True},
#  {'word': 'но',
#   'sent_len': 42,
#   'upos': 'CCONJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Cc',
#   'prev_word': '^',
#   'prev_word_upos': 'CCONJ',
#   'prev_word_xpos_type': 'punct',
#   'next_word': 'синовете',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'mpd',
#   'word_after_next_word': 'им',
#   'word_after_next_word_upos': 'PRON',
#   'word_after_next_word_xpos_type': 'Ps',
#   'word_after_next_word_xpos_gender_number_article': '',
#   'contains_publicistic_word': True},
#  {'word': 'синовете',
#   'sent_len': 42,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'mpd',
#   'prev_word': 'но',
#   'prev_word_upos': 'CCONJ',
#   'prev_word_xpos_type': 'Cc',
#   'word_before_prev_word': '^',
#   'word_before_prev_word_upos': 'CCONJ',
#   'word_before_prev_word_xpos_type': 'punct',
#   'next_word': 'им',
#   'next_word_upos': 'PRON',
#   'next_word_xpos_type': 'Ps',
#   'next_word_xpos_gender_number_article': '',
#   'word_after_next_word': 'не',
#   'word_after_next_word_upos': 'PART',
#   'word_after_next_word_xpos_type': 'Tn',
#   'contains_publicistic_word': True},
#  {'word': 'им',
#   'sent_len': 42,
#   'upos': 'PRON',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Ps',
#   'word_xpos_gender_number_article': '',
#   'prev_word': 'синовете',
#   'prev_word_upos': 'NOUN',
#   'prev_word_xpos_type': 'Nc',
#   'prev_word_xpos_gender_number_article': 'mpd',
#   'word_before_prev_word': 'но',
#   'word_before_prev_word_upos': 'CCONJ',
#   'word_before_prev_word_xpos_type': 'Cc',
#   'next_word': 'не',
#   'next_word_upos': 'PART',
#   'next_word_xpos_type': 'Tn',
#   'word_after_next_word': 'умъртви',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-s',
#   'contains_publicistic_word': True},
#  {'word': 'не',
#   'sent_len': 42,
#   'upos': 'PART',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Tn',
#   'prev_word': 'им',
#   'prev_word_upos': 'PRON',
#   'prev_word_xpos_type': 'Ps',
#   'prev_word_xpos_gender_number_article': '',
#   'word_before_prev_word': 'синовете',
#   'word_before_prev_word_upos': 'NOUN',
#   'word_before_prev_word_xpos_type': 'Nc',
#   'word_before_prev_word_xpos_gender_number_article': 'mpd',
#   'next_word': 'умъртви',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-s',
#   'word_after_next_word': 'защото',
#   'word_after_next_word_upos': 'ADV',
#   'word_after_next_word_xpos_type': 'Pr',
#   'word_after_next_word_xpos_gender_number_article': '',
#   'contains_publicistic_word': True},
#  {'word': 'умъртви',
#   'sent_len': 42,
#   'upos': 'VERB',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-s',
#   'prev_word': 'не',
#   'prev_word_upos': 'PART',
#   'prev_word_xpos_type': 'Tn',
#   'word_before_prev_word': 'им',
#   'word_before_prev_word_upos': 'PRON',
#   'word_before_prev_word_xpos_type': 'Ps',
#   'word_before_prev_word_xpos_gender_number_article': '',
#   'next_word': 'защото',
#   'next_word_upos': 'ADV',
#   'next_word_xpos_type': 'Pr',
#   'next_word_xpos_gender_number_article': '',
#   'word_after_next_word': 'постъпи',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-s',
#   'contains_publicistic_word': True},
#  {'word': 'защото',
#   'sent_len': 42,
#   'upos': 'ADV',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Pr',
#   'word_xpos_gender_number_article': '',
#   'prev_word': 'умъртви',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-s',
#   'word_before_prev_word': 'не',
#   'word_before_prev_word_upos': 'PART',
#   'word_before_prev_word_xpos_type': 'Tn',
#   'next_word': 'постъпи',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-s',
#   'word_after_next_word': 'според',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R',
#   'contains_publicistic_word': True},
#  {'word': 'постъпи',
#   'sent_len': 42,
#   'upos': 'VERB',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-s',
#   'prev_word': 'защото',
#   'prev_word_upos': 'ADV',
#   'prev_word_xpos_type': 'Pr',
#   'prev_word_xpos_gender_number_article': '',
#   'word_before_prev_word': 'умъртви',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-s',
#   'next_word': 'според',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'писаното',
#   'word_after_next_word_upos': 'ADJ',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': 'nsd',
#   'word_after_next_word_xpos_mood': 'c',
#   'contains_publicistic_word': True},
#  {'word': 'според',
#   'sent_len': 42,
#   'upos': 'ADP',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'R',
#   'prev_word': 'постъпи',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-s',
#   'word_before_prev_word': 'защото',
#   'word_before_prev_word_upos': 'ADV',
#   'word_before_prev_word_xpos_type': 'Pr',
#   'word_before_prev_word_xpos_gender_number_article': '',
#   'next_word': 'писаното',
#   'next_word_upos': 'ADJ',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': 'nsd',
#   'next_word_xpos_mood': 'c',
#   'word_after_next_word': 'в',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R',
#   'contains_publicistic_word': True},
#  {'word': 'писаното',
#   'sent_len': 42,
#   'upos': 'ADJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': 'nsd',
#   'word_xpos_mood': 'c',
#   'prev_word': 'според',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'постъпи',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-s',
#   'next_word': 'в',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'закона',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'msh',
#   'contains_publicistic_word': True},
#  {'word': 'в',
#   'sent_len': 42,
#   'upos': 'ADP',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'R',
#   'prev_word': 'писаното',
#   'prev_word_upos': 'ADJ',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': 'nsd',
#   'prev_word_xpos_mood': 'c',
#   'word_before_prev_word': 'според',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'закона',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'msh',
#   'word_after_next_word': 'в',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R',
#   'contains_publicistic_word': True},
#  {'word': 'закона',
#   'sent_len': 42,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'msh',
#   'prev_word': 'в',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'писаното',
#   'word_before_prev_word_upos': 'ADJ',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': 'nsd',
#   'word_before_prev_word_xpos_mood': 'c',
#   'next_word': 'в',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'книгата',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'fsd',
#   'contains_publicistic_word': True},
#  {'word': 'в',
#   'sent_len': 42,
#   'upos': 'ADP',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'R',
#   'prev_word': 'закона',
#   'prev_word_upos': 'NOUN',
#   'prev_word_xpos_type': 'Nc',
#   'prev_word_xpos_gender_number_article': 'msh',
#   'word_before_prev_word': 'в',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'книгата',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'fsd',
#   'word_after_next_word': 'на',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R',
#   'contains_publicistic_word': True},
#  {'word': 'книгата',
#   'sent_len': 42,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'fsd',
#   'prev_word': 'в',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'закона',
#   'word_before_prev_word_upos': 'NOUN',
#   'word_before_prev_word_xpos_type': 'Nc',
#   'word_before_prev_word_xpos_gender_number_article': 'msh',
#   'next_word': 'на',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'мойсей',
#   'word_after_next_word_upos': 'PROPN',
#   'word_after_next_word_xpos_type': 'Np',
#   'word_after_next_word_xpos_gender_number_article': 'msi',
#   'contains_publicistic_word': True},
#  {'word': 'на',
#   'sent_len': 42,
#   'upos': 'ADP',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'R',
#   'prev_word': 'книгата',
#   'prev_word_upos': 'NOUN',
#   'prev_word_xpos_type': 'Nc',
#   'prev_word_xpos_gender_number_article': 'fsd',
#   'word_before_prev_word': 'в',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'мойсей',
#   'next_word_upos': 'PROPN',
#   'next_word_xpos_type': 'Np',
#   'next_word_xpos_gender_number_article': 'msi',
#   'word_after_next_word': 'където',
#   'word_after_next_word_upos': 'ADV',
#   'word_after_next_word_xpos_type': 'Pr',
#   'word_after_next_word_xpos_gender_number_article': '',
#   'word_after_next_word_xpos_ref_type': 'l',
#   'contains_publicistic_word': True},
#  {'word': 'мойсей',
#   'sent_len': 42,
#   'upos': 'PROPN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Np',
#   'word_xpos_gender_number_article': 'msi',
#   'prev_word': 'на',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'книгата',
#   'word_before_prev_word_upos': 'NOUN',
#   'word_before_prev_word_xpos_type': 'Nc',
#   'word_before_prev_word_xpos_gender_number_article': 'fsd',
#   'next_word': 'където',
#   'next_word_upos': 'ADV',
#   'next_word_xpos_type': 'Pr',
#   'next_word_xpos_gender_number_article': '',
#   'next_word_xpos_ref_type': 'l',
#   'word_after_next_word': 'господ',
#   'word_after_next_word_upos': 'PROPN',
#   'word_after_next_word_xpos_type': 'Np',
#   'word_after_next_word_xpos_gender_number_article': 'msi',
#   'contains_publicistic_word': True},
#  {'word': 'където',
#   'sent_len': 42,
#   'upos': 'ADV',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Pr',
#   'word_xpos_gender_number_article': '',
#   'word_xpos_ref_type': 'l',
#   'prev_word': 'мойсей',
#   'prev_word_upos': 'PROPN',
#   'prev_word_xpos_type': 'Np',
#   'prev_word_xpos_gender_number_article': 'msi',
#   'word_before_prev_word': 'на',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'господ',
#   'next_word_upos': 'PROPN',
#   'next_word_xpos_type': 'Np',
#   'next_word_xpos_gender_number_article': 'msi',
#   'word_after_next_word': 'заповяда',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-s',
#   'contains_publicistic_word': True},
#  {'word': 'господ',
#   'sent_len': 42,
#   'upos': 'PROPN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Np',
#   'word_xpos_gender_number_article': 'msi',
#   'prev_word': 'където',
#   'prev_word_upos': 'ADV',
#   'prev_word_xpos_type': 'Pr',
#   'prev_word_xpos_gender_number_article': '',
#   'prev_word_xpos_ref_type': 'l',
#   'word_before_prev_word': 'мойсей',
#   'word_before_prev_word_upos': 'PROPN',
#   'word_before_prev_word_xpos_type': 'Np',
#   'word_before_prev_word_xpos_gender_number_article': 'msi',
#   'next_word': 'заповяда',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-s',
#   'word_after_next_word': 'и',
#   'word_after_next_word_upos': 'CCONJ',
#   'word_after_next_word_xpos_type': 'Cp',
#   'contains_publicistic_word': True},
#  {'word': 'заповяда',
#   'sent_len': 42,
#   'upos': 'VERB',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-s',
#   'prev_word': 'господ',
#   'prev_word_upos': 'PROPN',
#   'prev_word_xpos_type': 'Np',
#   'prev_word_xpos_gender_number_article': 'msi',
#   'word_before_prev_word': 'където',
#   'word_before_prev_word_upos': 'ADV',
#   'word_before_prev_word_xpos_type': 'Pr',
#   'word_before_prev_word_xpos_gender_number_article': '',
#   'word_before_prev_word_xpos_ref_type': 'l',
#   'next_word': 'и',
#   'next_word_upos': 'CCONJ',
#   'next_word_xpos_type': 'Cp',
#   'word_after_next_word': 'каза',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-s',
#   'contains_publicistic_word': True},
#  {'word': 'и',
#   'sent_len': 42,
#   'upos': 'CCONJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Cp',
#   'prev_word': 'заповяда',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-s',
#   'word_before_prev_word': 'господ',
#   'word_before_prev_word_upos': 'PROPN',
#   'word_before_prev_word_xpos_type': 'Np',
#   'word_before_prev_word_xpos_gender_number_article': 'msi',
#   'next_word': 'каза',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-s',
#   'word_after_next_word': 'бащите',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'mpd',
#   'contains_publicistic_word': True},
#  {'word': 'каза',
#   'sent_len': 42,
#   'upos': 'VERB',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-s',
#   'prev_word': 'и',
#   'prev_word_upos': 'CCONJ',
#   'prev_word_xpos_type': 'Cp',
#   'word_before_prev_word': 'заповяда',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-s',
#   'next_word': 'бащите',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'mpd',
#   'word_after_next_word': 'да',
#   'word_after_next_word_upos': 'AUX',
#   'word_after_next_word_xpos_type': 'Tx',
#   'contains_publicistic_word': True},
#  {'word': 'бащите',
#   'sent_len': 42,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'mpd',
#   'prev_word': 'каза',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-s',
#   'word_before_prev_word': 'и',
#   'word_before_prev_word_upos': 'CCONJ',
#   'word_before_prev_word_xpos_type': 'Cp',
#   'next_word': 'да',
#   'next_word_upos': 'AUX',
#   'next_word_xpos_type': 'Tx',
#   'word_after_next_word': 'не',
#   'word_after_next_word_upos': 'INTJ',
#   'word_after_next_word_xpos_type': 'Tn',
#   'contains_publicistic_word': True},
#  {'word': 'да',
#   'sent_len': 42,
#   'upos': 'AUX',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Tx',
#   'prev_word': 'бащите',
#   'prev_word_upos': 'NOUN',
#   'prev_word_xpos_type': 'Nc',
#   'prev_word_xpos_gender_number_article': 'mpd',
#   'word_before_prev_word': 'каза',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-s',
#   'next_word': 'не',
#   'next_word_upos': 'INTJ',
#   'next_word_xpos_type': 'Tn',
#   'word_after_next_word': 'умират',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-p',
#   'contains_publicistic_word': True},
#  {'word': 'не',
#   'sent_len': 42,
#   'upos': 'INTJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Tn',
#   'prev_word': 'да',
#   'prev_word_upos': 'AUX',
#   'prev_word_xpos_type': 'Tx',
#   'word_before_prev_word': 'бащите',
#   'word_before_prev_word_upos': 'NOUN',
#   'word_before_prev_word_xpos_type': 'Nc',
#   'word_before_prev_word_xpos_gender_number_article': 'mpd',
#   'next_word': 'умират',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-p',
#   'word_after_next_word': 'заради',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R',
#   'contains_publicistic_word': True},
#  {'word': 'умират',
#   'sent_len': 42,
#   'upos': 'VERB',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-p',
#   'prev_word': 'не',
#   'prev_word_upos': 'INTJ',
#   'prev_word_xpos_type': 'Tn',
#   'word_before_prev_word': 'да',
#   'word_before_prev_word_upos': 'AUX',
#   'word_before_prev_word_xpos_type': 'Tx',
#   'next_word': 'заради',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'синовете',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'mpd',
#   'contains_publicistic_word': True},
#  {'word': 'заради',
#   'sent_len': 42,
#   'upos': 'ADP',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'R',
#   'prev_word': 'умират',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-p',
#   'word_before_prev_word': 'не',
#   'word_before_prev_word_upos': 'INTJ',
#   'word_before_prev_word_xpos_type': 'Tn',
#   'next_word': 'синовете',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'mpd',
#   'word_after_next_word': 'и',
#   'word_after_next_word_upos': 'CCONJ',
#   'word_after_next_word_xpos_type': 'Cp',
#   'contains_publicistic_word': True},
#  {'word': 'синовете',
#   'sent_len': 42,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': True,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'mpd',
#   'prev_word': 'заради',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'умират',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-p',
#   'next_word': 'и',
#   'next_word_upos': 'CCONJ',
#   'next_word_xpos_type': 'Cp',
#   'word_after_next_word': 'синовете',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'mpd',
#   'contains_publicistic_word': True},
#  {'word': 'и',
#   'sent_len': 42,
#   'upos': 'CCONJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Cp',
#   'prev_word': 'синовете',
#   'prev_word_upos': 'NOUN',
#   'prev_word_xpos_type': 'Nc',
#   'prev_word_xpos_gender_number_article': 'mpd',
#   'word_before_prev_word': 'заради',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'синовете',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'mpd',
#   'word_after_next_word': 'да',
#   'word_after_next_word_upos': 'AUX',
#   'word_after_next_word_xpos_type': 'Tx',
#   'contains_publicistic_word': True},
#  {'word': 'синовете',
#   'sent_len': 42,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'mpd',
#   'prev_word': 'и',
#   'prev_word_upos': 'CCONJ',
#   'prev_word_xpos_type': 'Cp',
#   'word_before_prev_word': 'синовете',
#   'word_before_prev_word_upos': 'NOUN',
#   'word_before_prev_word_xpos_type': 'Nc',
#   'word_before_prev_word_xpos_gender_number_article': 'mpd',
#   'next_word': 'да',
#   'next_word_upos': 'AUX',
#   'next_word_xpos_type': 'Tx',
#   'word_after_next_word': 'не',
#   'word_after_next_word_upos': 'INTJ',
#   'word_after_next_word_xpos_type': 'Tn',
#   'contains_publicistic_word': True},
#  {'word': 'да',
#   'sent_len': 42,
#   'upos': 'AUX',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Tx',
#   'prev_word': 'синовете',
#   'prev_word_upos': 'NOUN',
#   'prev_word_xpos_type': 'Nc',
#   'prev_word_xpos_gender_number_article': 'mpd',
#   'word_before_prev_word': 'и',
#   'word_before_prev_word_upos': 'CCONJ',
#   'word_before_prev_word_xpos_type': 'Cp',
#   'next_word': 'не',
#   'next_word_upos': 'INTJ',
#   'next_word_xpos_type': 'Tn',
#   'word_after_next_word': 'умират',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-p',
#   'contains_publicistic_word': True},
#  {'word': 'не',
#   'sent_len': 42,
#   'upos': 'INTJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Tn',
#   'prev_word': 'да',
#   'prev_word_upos': 'AUX',
#   'prev_word_xpos_type': 'Tx',
#   'word_before_prev_word': 'синовете',
#   'word_before_prev_word_upos': 'NOUN',
#   'word_before_prev_word_xpos_type': 'Nc',
#   'word_before_prev_word_xpos_gender_number_article': 'mpd',
#   'next_word': 'умират',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-p',
#   'word_after_next_word': 'заради',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R',
#   'contains_publicistic_word': True},
#  {'word': 'умират',
#   'sent_len': 42,
#   'upos': 'VERB',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-p',
#   'prev_word': 'не',
#   'prev_word_upos': 'INTJ',
#   'prev_word_xpos_type': 'Tn',
#   'word_before_prev_word': 'да',
#   'word_before_prev_word_upos': 'AUX',
#   'word_before_prev_word_xpos_type': 'Tx',
#   'next_word': 'заради',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'бащите',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'mpd',
#   'contains_publicistic_word': True},
#  {'word': 'заради',
#   'sent_len': 42,
#   'upos': 'ADP',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'R',
#   'prev_word': 'умират',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-p',
#   'word_before_prev_word': 'не',
#   'word_before_prev_word_upos': 'INTJ',
#   'word_before_prev_word_xpos_type': 'Tn',
#   'next_word': 'бащите',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'mpd',
#   'word_after_next_word': 'а',
#   'word_after_next_word_upos': 'CCONJ',
#   'word_after_next_word_xpos_type': 'Cp',
#   'contains_publicistic_word': True},
#  {'word': 'бащите',
#   'sent_len': 42,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': True,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'mpd',
#   'prev_word': 'заради',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'умират',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-p',
#   'next_word': 'а',
#   'next_word_upos': 'CCONJ',
#   'next_word_xpos_type': 'Cp',
#   'word_after_next_word': 'всеки',
#   'word_after_next_word_upos': 'PRON',
#   'word_after_next_word_xpos_type': 'Pc',
#   'word_after_next_word_xpos_gender_number_article': 'ms',
#   'word_after_next_word_xpos_ref_type': 'e',
#   'contains_publicistic_word': True},
#  {'word': 'а',
#   'sent_len': 42,
#   'upos': 'CCONJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Cp',
#   'prev_word': 'бащите',
#   'prev_word_upos': 'NOUN',
#   'prev_word_xpos_type': 'Nc',
#   'prev_word_xpos_gender_number_article': 'mpd',
#   'word_before_prev_word': 'заради',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'всеки',
#   'next_word_upos': 'PRON',
#   'next_word_xpos_type': 'Pc',
#   'next_word_xpos_gender_number_article': 'ms',
#   'next_word_xpos_ref_type': 'e',
#   'word_after_next_word': 'да',
#   'word_after_next_word_upos': 'AUX',
#   'word_after_next_word_xpos_type': 'Tx',
#   'contains_publicistic_word': True},
#  {'word': 'всеки',
#   'sent_len': 42,
#   'upos': 'PRON',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Pc',
#   'word_xpos_gender_number_article': 'ms',
#   'word_xpos_ref_type': 'e',
#   'prev_word': 'а',
#   'prev_word_upos': 'CCONJ',
#   'prev_word_xpos_type': 'Cp',
#   'word_before_prev_word': 'бащите',
#   'word_before_prev_word_upos': 'NOUN',
#   'word_before_prev_word_xpos_type': 'Nc',
#   'word_before_prev_word_xpos_gender_number_article': 'mpd',
#   'next_word': 'да',
#   'next_word_upos': 'AUX',
#   'next_word_xpos_type': 'Tx',
#   'word_after_next_word': 'умира',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-s',
#   'contains_publicistic_word': True},
#  {'word': 'да',
#   'sent_len': 42,
#   'upos': 'AUX',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Tx',
#   'prev_word': 'всеки',
#   'prev_word_upos': 'PRON',
#   'prev_word_xpos_type': 'Pc',
#   'prev_word_xpos_gender_number_article': 'ms',
#   'prev_word_xpos_ref_type': 'e',
#   'word_before_prev_word': 'а',
#   'word_before_prev_word_upos': 'CCONJ',
#   'word_before_prev_word_xpos_type': 'Cp',
#   'next_word': 'умира',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-s',
#   'word_after_next_word': 'за',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R',
#   'contains_publicistic_word': True},
#  {'word': 'умира',
#   'sent_len': 42,
#   'upos': 'VERB',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-s',
#   'prev_word': 'да',
#   'prev_word_upos': 'AUX',
#   'prev_word_xpos_type': 'Tx',
#   'word_before_prev_word': 'всеки',
#   'word_before_prev_word_upos': 'PRON',
#   'word_before_prev_word_xpos_type': 'Pc',
#   'word_before_prev_word_xpos_gender_number_article': 'ms',
#   'word_before_prev_word_xpos_ref_type': 'e',
#   'next_word': 'за',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'собствения',
#   'word_after_next_word_upos': 'ADJ',
#   'word_after_next_word_xpos_type': 'A',
#   'word_after_next_word_xpos_gender_number_article': 'msh',
#   'contains_publicistic_word': True},
#  {'word': 'за',
#   'sent_len': 42,
#   'upos': 'ADP',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'R',
#   'prev_word': 'умира',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-s',
#   'word_before_prev_word': 'да',
#   'word_before_prev_word_upos': 'AUX',
#   'word_before_prev_word_xpos_type': 'Tx',
#   'next_word': 'собствения',
#   'next_word_upos': 'ADJ',
#   'next_word_xpos_type': 'A',
#   'next_word_xpos_gender_number_article': 'msh',
#   'word_after_next_word': 'си',
#   'word_after_next_word_upos': 'PRON',
#   'word_after_next_word_xpos_type': 'Ps',
#   'word_after_next_word_xpos_gender_number_article': '',
#   'contains_publicistic_word': True},
#  {'word': 'собствения',
#   'sent_len': 42,
#   'upos': 'ADJ',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'A',
#   'word_xpos_gender_number_article': 'msh',
#   'prev_word': 'за',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'умира',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-s',
#   'next_word': 'си',
#   'next_word_upos': 'PRON',
#   'next_word_xpos_type': 'Ps',
#   'next_word_xpos_gender_number_article': '',
#   'word_after_next_word': 'грях',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'msi',
#   'contains_publicistic_word': True},
#  {'word': 'си',
#   'sent_len': 42,
#   'upos': 'PRON',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Ps',
#   'word_xpos_gender_number_article': '',
#   'prev_word': 'собствения',
#   'prev_word_upos': 'ADJ',
#   'prev_word_xpos_type': 'A',
#   'prev_word_xpos_gender_number_article': 'msh',
#   'word_before_prev_word': 'за',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'грях',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'msi',
#   'contains_publicistic_word': True},
#  {'word': 'грях',
#   'sent_len': 42,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'но',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'msi',
#   'prev_word': 'си',
#   'prev_word_upos': 'PRON',
#   'prev_word_xpos_type': 'Ps',
#   'prev_word_xpos_gender_number_article': '',
#   'word_before_prev_word': 'собствения',
#   'word_before_prev_word_upos': 'ADJ',
#   'word_before_prev_word_xpos_type': 'A',
#   'word_before_prev_word_xpos_gender_number_article': 'msh',
#   'EOS': True,
#   'contains_publicistic_word': True}]

# %%
v = DictVectorizer()
X_train_60_svm = v.fit_transform(X_train_60_flat)
X_dev_svm = v.transform(X_dev_flat)

# %%
le = preprocessing.LabelEncoder()
y_train_60_svm = le.fit_transform(y_train_60_flat)
y_dev_svm = le.transform(y_dev_flat)

# %%
le.classes_
# Out:
# array(['', '!', '"', '",', '".', '(', ')', '),', ').', ',', '-', '.',
#        '...', ':', ':"', ';', '?'], dtype='<U3')

# %% [markdown]
# ### SVM Model

# %%
# %%time
clf = LinearSVC()
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# CPU times: user 2h 49min 18s, sys: 10.5 s, total: 2h 49min 28s
# Wall time: 2h 49min 34s
# /Users/mter0707/opt/anaconda3/envs/masters/lib/python3.6/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC()

# %%
pkl_filename = '../../data/svm_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)

# %%
y_pred = clf.predict(X_dev_svm)

# %%
target_names = list(le.classes_)

# %%
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.969     0.975     0.972    240418
#            !      0.477     0.279     0.352       373
#            "      0.493     0.242     0.324      2243
#           ",      0.686     0.591     0.635       848
#           ".      0.282     0.197     0.232       300
#            (      0.882     0.913     0.897      1693
#            )      0.856     0.854     0.855      1003
#           ),      0.768     0.670     0.716       385
#           ).      0.908     0.945     0.926       271
#            ,      0.694     0.727     0.710     18651
#            -      0.332     0.135     0.192       935
#            .      0.951     0.968     0.959     11435
#          ...      0.200     0.043     0.071        70
#            :      0.692     0.689     0.691       935
#           :"      0.538     0.103     0.173        68
#            ;      0.150     0.073     0.098       628
#            ?      0.747     0.859     0.799       453
#
#     accuracy                          0.942    280709
#    macro avg      0.625     0.545     0.565    280709
# weighted avg      0.937     0.942     0.939    280709

# %%
target_names.remove('')

# %%
labels.remove(0)

# %%
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            !      0.477     0.279     0.352       373
#            "      0.493     0.242     0.324      2243
#           ",      0.686     0.591     0.635       848
#           ".      0.282     0.197     0.232       300
#            (      0.882     0.913     0.897      1693
#            )      0.856     0.854     0.855      1003
#           ),      0.768     0.670     0.716       385
#           ).      0.908     0.945     0.926       271
#            ,      0.694     0.727     0.710     18651
#            -      0.332     0.135     0.192       935
#            .      0.951     0.968     0.959     11435
#          ...      0.200     0.043     0.071        70
#            :      0.692     0.689     0.691       935
#           :"      0.538     0.103     0.173        68
#            ;      0.150     0.073     0.098       628
#            ?      0.747     0.859     0.799       453
#
#    micro avg      0.769     0.743     0.756     40291
#    macro avg      0.604     0.518     0.539     40291
# weighted avg      0.747     0.743     0.741     40291

# %%
actual_y_pred = le.inverse_transform(y_pred)

# %%
punctuated_sentences = scikit_punctuate(X_dev_flat, actual_y_pred)

# %%
print(punctuated_sentences[:10679])
# Out:
# но синовете им не умъртви, защото постъпи според писаното в закона, в книгата на мойсей, където господ заповяда и каза: бащите, да не умират заради синовете и синовете да не умират заради бащите, а всеки да умира за собствения си грях. но когато ти говоря, ще отворя устата ти и ти им кажи: така казва господ, бог, който слуша, нека слуша, а който не слуша, нека не слуша, защото са бунтовен дом. защото кой е по-голям, този, който седи на трапезата ли или онзи, който слугува? а след това ще се насели, както в предишните дни, заявява господ. а той беше на задната част заспал на възглавница. ефрем е като птица славата му ще отлети. и така той си отиде от него на известно разстояние. не бягам при халдейците. и израилевите синове излязоха от египетската земя, строени. а когато ахитофел видя, че съветът му не се изпълни оседла магарето си и стана и отиде у дома си в своя град и нареди домашните си, работи и се обеси. ако умре някое животно от добитъка, който можете да ядете, който се допре до мършата му, ще бъде нечист до вечерта. но помощник съответен на адам, не се намери. който задържа жито, народът ще го проклина, а благословение ще почива на главата на този, който го продава. този човек беше праведен, и благочестив и чакаше, утехата на израил и светият дух беше на него. всичко е възможно за този, който вярва. и видях височината на дома околовръст, основите на страничните стаи бяха една цяла тръстика от шест големи лакътя. после да вземеш тлъстината на овена, опашката и тлъстината, която покрива, вътрешностите, булото на дроба, двата бъбрека с тлъстината, която е около тях и дясното бедро, защото е овен на посвещение; и един хляб, една пита хляб, месен с маслинено масло; и една кора от коша на безквасните хлябове, които са пред господа. и от дима излязоха скакалци по земята и им се даде власт като властта, която имат земните скорпиони. ти си, господи, само ти! и ще предаде израил заради греховете на еровоам, с които съгреши и с които въведе израил в грях. синове на елифаз: теман: и омар, сефи и готом, кенез, и тамна и амалик. а гладът в самария беше страшен. затова казах в сърцето си, че и това е суета. насладих се на сянката му и седнах и плодът му, бе сладък в устата ми. защото така ми каза: господ, както ръмжи над лова си, лъвът младият лъв, срещу когото се свикват множество овчари и не се плаши от гласа им, и не се отдръпва, пред шума им, така, господ на войнствата: ще слезе, за да воюва за хълма сион и за неговото възвишение. отче, свети, опази ги в името си, което си ми дал, за да бъдат едно, както сме и ние. и да правите разлика между чистите животни, и нечистите и между нечистите птици, и чистите и да не осквернявате себе си с животно, или с птица, или с каквото и да е, което пълзи по земята, което аз съм ви отделил като нечисто. и господ укрепи моавския цар еглон против израил, защото вършиха зло пред господа. и духът ми каза: да отида с тях, без да се двоумя. в двадесет и седмата година на израилевия цар еровоам се възцари азария, синът на юдовия цар амасия. защото вашата послушност е известна на всички, затова се радвам за вас! той изтегля, всички с въдица влачи ги в мрежата си и ги събира в рибарската си мрежа, затова се радва и се весели. благословен да е господ бог, богът! на израил, който единствен върши чудеса! и които влязоха мъжко и женско от всяка плът, влязоха както бог му беше заповядал и господ, затвори след него. тогава царят каза на божия човек: ела с мен у дома и се подкрепи и ще ти дам подарък. и ето, въпреки че е посадена ще успее ли? от дома тогарма, даваха за стоките ти коне бойни коне, и мулета. затова, заповядай, гробът да се пази здраво до третия, ден да не би учениците му да дойдат и да го откраднат, и да кажат на народа възкръсна от мъртвите. и когато отвори петия печат, видях под олтара, душите на онези, които са били заклани за божието слово и за свидетелството, което държаха. и свещениците, които служат на господа са синовете на аарон и левитите са в службата. той тича след тях с умолителни дум ...

# %% [markdown]
# #### Results: Better recall and worse precision compared to CRF's equivalent

# %% [markdown]
# ### SVM - scaled data, dual=False, balanced classed_weight, incresed C and lower max_iter

# %%
# %%time
clf = make_pipeline(StandardScaler(with_mean=False), LinearSVC(dual=False, class_weight='balanced', C=1.5, max_iter=200))
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# CPU times: user 1h 2min 34s, sys: 6min 41s, total: 1h 9min 16s
# Wall time: 12min 27s
# /Users/mter0707/opt/anaconda3/envs/masters/lib/python3.6/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Pipeline(steps=[('standardscaler', StandardScaler(with_mean=False)),
#                 ('linearsvc',
#                  LinearSVC(C=1.5, class_weight='balanced', dual=False,
#                            max_iter=200))])

# %%
pkl_filename = '../../data/svm_v2_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_dev_svm)
target_names = list(le.classes_)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
target_names.remove('')
labels.remove(0)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.970     0.948     0.959    240418
#            !      0.245     0.279     0.261       373
#            "      0.271     0.401     0.323      2243
#           ",      0.486     0.554     0.518       848
#           ".      0.130     0.153     0.141       300
#            (      0.885     0.894     0.889      1693
#            )      0.669     0.821     0.737      1003
#           ),      0.563     0.673     0.613       385
#           ).      0.612     0.900     0.728       271
#            ,      0.625     0.669     0.647     18651
#            -      0.100     0.173     0.127       935
#            .      0.931     0.951     0.941     11435
#          ...      0.038     0.071     0.049        70
#            :      0.486     0.718     0.579       935
#           :"      0.070     0.176     0.100        68
#            ;      0.083     0.188     0.115       628
#            ?      0.568     0.603     0.585       453
#
#     accuracy                          0.915    280709
#    macro avg      0.455     0.540     0.489    280709
# weighted avg      0.926     0.915     0.920    280709
#
#               precision    recall  f1-score   support
#
#            !      0.245     0.279     0.261       373
#            "      0.271     0.401     0.323      2243
#           ",      0.486     0.554     0.518       848
#           ".      0.130     0.153     0.141       300
#            (      0.885     0.894     0.889      1693
#            )      0.669     0.821     0.737      1003
#           ),      0.563     0.673     0.613       385
#           ).      0.612     0.900     0.728       271
#            ,      0.625     0.669     0.647     18651
#            -      0.100     0.173     0.127       935
#            .      0.931     0.951     0.941     11435
#          ...      0.038     0.071     0.049        70
#            :      0.486     0.718     0.579       935
#           :"      0.070     0.176     0.100        68
#            ;      0.083     0.188     0.115       628
#            ?      0.568     0.603     0.585       453
#
#    micro avg      0.633     0.719     0.673     40291
#    macro avg      0.423     0.514     0.460     40291
# weighted avg      0.667     0.719     0.690     40291

# %% [markdown]
# #### Result: Maybe the iterations were too little

# %% [markdown]
# ### SVM - scaled data, dual=False, balanced classed_weight, incresed C

# %%
# %%time
clf = make_pipeline(StandardScaler(with_mean=False), LinearSVC(dual=False, class_weight='balanced', C=1.5))
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# CPU times: user 4h 12min 53s, sys: 28min 38s, total: 4h 41min 32s
# Wall time: 50min 20s
# Pipeline(steps=[('standardscaler', StandardScaler(with_mean=False)),
#                 ('linearsvc',
#                  LinearSVC(C=1.5, class_weight='balanced', dual=False))])

# %%
pkl_filename = '../../data/svm_v3_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_dev_svm)
target_names = list(le.classes_)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
target_names.remove('')
labels.remove(0)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.969     0.949     0.959    240418
#            !      0.235     0.284     0.257       373
#            "      0.270     0.396     0.321      2243
#           ",      0.502     0.540     0.520       848
#           ".      0.121     0.140     0.130       300
#            (      0.886     0.893     0.890      1693
#            )      0.705     0.809     0.753      1003
#           ),      0.581     0.673     0.623       385
#           ).      0.635     0.893     0.742       271
#            ,      0.620     0.666     0.643     18651
#            -      0.101     0.170     0.127       935
#            .      0.928     0.946     0.937     11435
#          ...      0.038     0.057     0.046        70
#            :      0.485     0.705     0.574       935
#           :"      0.079     0.176     0.109        68
#            ;      0.093     0.180     0.123       628
#            ?      0.583     0.598     0.590       453
#
#     accuracy                          0.916    280709
#    macro avg      0.461     0.534     0.491    280709
# weighted avg      0.926     0.916     0.920    280709
#
#               precision    recall  f1-score   support
#
#            !      0.235     0.284     0.257       373
#            "      0.270     0.396     0.321      2243
#           ",      0.502     0.540     0.520       848
#           ".      0.121     0.140     0.130       300
#            (      0.886     0.893     0.890      1693
#            )      0.705     0.809     0.753      1003
#           ),      0.581     0.673     0.623       385
#           ).      0.635     0.893     0.742       271
#            ,      0.620     0.666     0.643     18651
#            -      0.101     0.170     0.127       935
#            .      0.928     0.946     0.937     11435
#          ...      0.038     0.057     0.046        70
#            :      0.485     0.705     0.574       935
#           :"      0.079     0.176     0.109        68
#            ;      0.093     0.180     0.123       628
#            ?      0.583     0.598     0.590       453
#
#    micro avg      0.636     0.715     0.673     40291
#    macro avg      0.429     0.508     0.462     40291
# weighted avg      0.666     0.715     0.688     40291

# %%
actual_y_pred = le.inverse_transform(y_pred)
punctuated_sentences = scikit_punctuate(X_dev_flat, actual_y_pred)
print(punctuated_sentences[:10735])
# Out:
# но синовете им не умъртви, защото постъпи според писаното в закона, в книгата на мойсей, където господ заповяда и каза: бащите, да не умират заради синовете и синовете да не умират заради бащите, а всеки да умира за собствения си грях. но когато ти говоря- ще отворя устата ти и ти им кажи: така казва господ: бог, който слуша, нека слуша; а който не слуша; нека не слуша; защото са бунтовен дом. защото:" кой е по-голям, този, който седи на трапезата ли или онзи, който слугува? а след това ще се насели, както в предишните дни, заявява господ. а той беше на задната част; заспал на възглавница. ефрем е като птица" славата му ще отлети. и така той си отиде от него на известно разстояние! не бягам при халдейците. и израилевите синове излязоха от египетската земя, строени. а когато ахитофел видя, че съветът му не се изпълни оседла магарето си, и стана и отиде у дома си в своя град и нареди домашните си, работи; и се обеси. ако умре някое животно от добитъка, който можете да ядете, който се допре до мършата му, ще бъде нечист до вечерта. но помощник съответен на адам, не се намери. който задържа жито, народът, ще го проклина, а благословение- ще почива на главата- на този, който го продава. този човек беше праведен, и благочестив и чакаше, утехата на израил и светият дух:" беше на него. всичко е възможно; за този, който вярва. и видях височината на дома околовръст основите на страничните стаи бяха една цяла тръстика от шест големи лакътя. после да вземеш тлъстината на овена, опашката, и тлъстината, която покрива вътрешностите, булото на дроба, двата бъбрека с тлъстината, която е около тях и дясното бедро; защото е овен на посвещение и един хляб- една пита хляб. месен с маслинено масло; и една кора от коша на безквасните хлябове, които са пред господа. и от дима излязоха скакалци, по земята и им се даде власт като властта, която имат земните скорпиони. ти си, господи, само ти? и ще предаде израил заради греховете на еровоам, с които съгреши и с които въведе израил в грях. синове на елифаз: теман: и омар, сефи и готом, кенез и тамна и амалик. а гладът в самария беше страшен. затова казах в сърцето си, че и това е суета. насладих се на сянката му и седнах и плодът му, бе сладък в устата ми. защото така ми каза: господ, както ръмжи над лова си; лъвът младият лъв срещу когото се свикват множество овчари, и не, се плаши от гласа им" и не се отдръпва, пред шума им, така, господ на войнствата: ще слезе, за да воюва за хълма сион, и за неговото възвишение. отче, свети, опази ги в името си, което си ми дал, за да бъдат едно, както сме и ние. и да правите разлика между чистите животни и нечистите и между нечистите птици и чистите и да не осквернявате себе си с животно, или с птица" или с каквото и да е, което пълзи по земята, което аз съм ви отделил като нечисто. и господ укрепи моавския цар еглон, против израил, защото вършиха зло пред господа. и духът ми каза: да отида с тях, без да се двоумя. в двадесет и седмата година на израилевия цар: еровоам се възцари азария, синът на юдовия цар амасия. защото вашата послушност е известна на всички; затова се радвам за вас! той изтегля, всички с въдица влачи ги, в мрежата си и ги събира в рибарската си- мрежа" затова се радва и се весели. благословен да е господ бог, богът! на израил, който единствен върши чудеса". и които влязоха мъжко и женско; от всяка плът, влязоха както бог му беше заповядал; и господ, затвори след него. тогава царят каза на божия човек: ела с мен у дома и се подкрепи и ще ти дам подарък. и ето, въпреки че е посадена ще успее ли? от дома тогарма, даваха за стоките ти коне бойни коне, и мулета. затова заповядай гробът да се пази здраво до третия, ден; да не би учениците му да дойдат и да го! откраднат, и да кажат на народа възкръсна от мъртвите! и когато отвори петия печат, видях под олтара душите на онези, които са били заклани за божието слово и за свидетелството, което държаха. и свещениците, които служат на господа са синовете на аарон и левитите са в службата. той тича след тях  ...

# %% [markdown]
# #### No great difference compared to max_iter=200

# %% [markdown]
# ### SVM - scaled data, dual=False, balanced classed_weight

# %%
# %%time
clf = make_pipeline(StandardScaler(with_mean=False), LinearSVC(dual=False, class_weight='balanced'))
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# UsageError: Line magic function `%%time` not found.

# %%
pkl_filename = '../../data/svm_v4_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_dev_svm)
target_names = list(le.classes_)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
target_names.remove('')
labels.remove(0)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.969     0.949     0.959    240418
#            !      0.232     0.279     0.253       373
#            "      0.270     0.396     0.321      2243
#           ",      0.495     0.541     0.517       848
#           ".      0.122     0.140     0.130       300
#            (      0.886     0.893     0.890      1693
#            )      0.707     0.808     0.754      1003
#           ),      0.578     0.673     0.622       385
#           ).      0.635     0.893     0.742       271
#            ,      0.621     0.665     0.642     18651
#            -      0.101     0.170     0.127       935
#            .      0.928     0.947     0.937     11435
#          ...      0.038     0.057     0.046        70
#            :      0.485     0.705     0.575       935
#           :"      0.078     0.176     0.108        68
#            ;      0.091     0.174     0.119       628
#            ?      0.586     0.600     0.593       453
#
#     accuracy                          0.916    280709
#    macro avg      0.460     0.533     0.490    280709
# weighted avg      0.926     0.916     0.920    280709
#
#               precision    recall  f1-score   support
#
#            !      0.232     0.279     0.253       373
#            "      0.270     0.396     0.321      2243
#           ",      0.495     0.541     0.517       848
#           ".      0.122     0.140     0.130       300
#            (      0.886     0.893     0.890      1693
#            )      0.707     0.808     0.754      1003
#           ),      0.578     0.673     0.622       385
#           ).      0.635     0.893     0.742       271
#            ,      0.621     0.665     0.642     18651
#            -      0.101     0.170     0.127       935
#            .      0.928     0.947     0.937     11435
#          ...      0.038     0.057     0.046        70
#            :      0.485     0.705     0.575       935
#           :"      0.078     0.176     0.108        68
#            ;      0.091     0.174     0.119       628
#            ?      0.586     0.600     0.593       453
#
#    micro avg      0.637     0.714     0.673     40291
#    macro avg      0.428     0.507     0.461     40291
# weighted avg      0.666     0.714     0.688     40291

# %% [markdown]
# #### Result: There was a better performance with a higher C

# %% [markdown]
# ### SVM - scaled data, dual=False and C=3

# %%
# %%time
clf = make_pipeline(StandardScaler(with_mean=False), LinearSVC(dual=False, C=3))
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# CPU times: user 4h 9min 24s, sys: 29min 6s, total: 4h 38min 30s
# Wall time: 49min 23s
# Pipeline(steps=[('standardscaler', StandardScaler(with_mean=False)),
#                 ('linearsvc', LinearSVC(C=3, dual=False))])

# %%
pkl_filename = '../../data/svm_v5_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_dev_svm)
target_names = list(le.classes_)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
target_names.remove('')
labels.remove(0)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.962     0.969     0.966    240418
#            !      0.247     0.236     0.241       373
#            "      0.319     0.251     0.281      2243
#           ",      0.502     0.501     0.501       848
#           ".      0.088     0.117     0.100       300
#            (      0.898     0.888     0.893      1693
#            )      0.747     0.769     0.758      1003
#           ),      0.484     0.657     0.557       385
#           ).      0.739     0.908     0.815       271
#            ,      0.709     0.620     0.662     18651
#            -      0.113     0.142     0.126       935
#            .      0.934     0.946     0.940     11435
#          ...      0.051     0.057     0.054        70
#            :      0.517     0.634     0.570       935
#           :"      0.103     0.088     0.095        68
#            ;      0.072     0.080     0.076       628
#            ?      0.546     0.678     0.605       453
#
#     accuracy                          0.928    280709
#    macro avg      0.472     0.502     0.485    280709
# weighted avg      0.927     0.928     0.927    280709
#
#               precision    recall  f1-score   support
#
#            !      0.247     0.236     0.241       373
#            "      0.319     0.251     0.281      2243
#           ",      0.502     0.501     0.501       848
#           ".      0.088     0.117     0.100       300
#            (      0.898     0.888     0.893      1693
#            )      0.747     0.769     0.758      1003
#           ),      0.484     0.657     0.557       385
#           ).      0.739     0.908     0.815       271
#            ,      0.709     0.620     0.662     18651
#            -      0.113     0.142     0.126       935
#            .      0.934     0.946     0.940     11435
#          ...      0.051     0.057     0.054        70
#            :      0.517     0.634     0.570       935
#           :"      0.103     0.088     0.095        68
#            ;      0.072     0.080     0.076       628
#            ?      0.546     0.678     0.605       453
#
#    micro avg      0.710     0.679     0.694     40291
#    macro avg      0.442     0.473     0.455     40291
# weighted avg      0.713     0.679     0.694     40291

# %% [markdown]
# #### Results: Drop in recall but greater precision

# %%
actual_y_pred = le.inverse_transform(y_pred)
punctuated_sentences = scikit_punctuate(X_dev_flat, actual_y_pred)
print(punctuated_sentences[:10671])
# Out:
# но синовете им не умъртви, защото постъпи според писаното в закона в книгата на мойсей, където господ заповяда и каза бащите да не умират заради синовете и синовете да не умират заради бащите, а всеки да умира за собствения си грях. но когато ти говоря- ще отворя устата ти и ти им кажи: така казва господ, бог, който слуша, нека слуша; а който не слуша, нека не слуша, защото са бунтовен дом. защото кой е по-голям, този, който седи на трапезата ли или онзи, който слугува? а след това ще се насели, както в предишните дни, заявява господ. а той беше на задната част; заспал на възглавница. ефрем е като птица славата му ще отлети. и така той си отиде от него на известно разстояние! не бягам при халдейците. и израилевите синове излязоха от египетската земя, строени. а когато ахитофел видя, че съветът му не се изпълни оседла магарето си, и стана и отиде у дома си в своя град и нареди домашните си, работи; и се обеси. ако умре някое животно от добитъка, който можете да ядете, който се допре до мършата му, ще бъде нечист до вечерта. но помощник съответен на адам, не се намери. който задържа жито, народът, ще го проклина, а благословение- ще почива на главата- на този, който го продава. този човек беше праведен, и благочестив и чакаше, утехата на израил и светият дух беше на него. всичко е възможно за този, който вярва. и видях височината на дома околовръст основите на" страничните стаи бяха една цяла тръстика от шест големи лакътя. после да вземеш тлъстината на овена, опашката, и тлъстината, която покрива вътрешностите, булото на дроба, двата бъбрека с тлъстината, която е около тях и дясното бедро; защото е овен на посвещение и един хляб, една пита хляб. месен с маслинено масло; и една кора от коша на безквасните хлябове, които са пред господа. и от дима излязоха скакалци по земята и им се даде власт като властта, която имат земните скорпиони. ти си, господи, само ти? и ще предаде израил заради греховете на еровоам, с които съгреши и с които въведе израил в грях. синове на елифаз: теман: и омар, сефи и готом, кенез, и тамна и амалик. а гладът в самария беше страшен. затова казах в сърцето си, че и това е суета. насладих се на сянката му и седнах и плодът му, бе сладък в устата ми. защото така ми каза господ, както ръмжи над лова си; лъвът младият лъв, срещу когото се свикват множество овчари и не, се плаши от гласа им, и не се отдръпва пред шума им; така господ на войнствата ще слезе за да воюва за хълма сион и за неговото възвишение. отче, свети, опази ги в името си, което си ми дал, за да бъдат едно, както сме и ние. и да правите разлика между чистите животни и нечистите и между нечистите птици и чистите и да не осквернявате себе си с животно, или с птица или с каквото и да е, което пълзи по земята, което аз съм ви отделил като нечисто. и господ укрепи моавския цар еглон против израил, защото вършиха зло пред господа. и духът ми каза: да отида с тях, без да се двоумя. в двадесет и седмата година на израилевия цар: еровоам се възцари азария, синът на юдовия цар амасия. защото вашата послушност е известна на всички; затова се радвам за вас! той изтегля всички с въдица влачи ги, в мрежата си и ги събира в рибарската си мрежа" затова се радва и се весели. благословен да е господ бог! богът! на израил, който единствен върши чудеса". и които влязоха мъжко и женско от всяка плът, влязоха както бог му беше заповядал и господ затвори след него. тогава царят каза на божия човек: ела с мен у дома и се подкрепи и ще ти дам подарък. и ето, въпреки че е посадена ще успее ли? от дома тогарма, даваха за стоките ти коне бойни коне, и мулета. затова, заповядай гробът да се пази здраво до третия, ден да не би учениците му да дойдат и да го откраднат и да кажат на народа възкръсна от мъртвите. и когато отвори петия печат, видях под олтара душите на онези, които са били заклани за божието слово и за свидетелството, което държаха. и свещениците, които служат на господа са синовете на аарон и левитите са в службата. той тича след тях с умолителни думи, но т ...

# %% [markdown]
# ### SVM - scaled data, dual=False and C=3, class_weight='balanced'

# %%
# %%time
clf = make_pipeline(StandardScaler(with_mean=False), LinearSVC(dual=False, C=3, class_weight='balanced'))
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# CPU times: user 4h 10min 36s, sys: 31min 22s, total: 4h 41min 58s
# Wall time: 52min 28s
# /Users/mter0707/opt/anaconda3/envs/masters/lib/python3.6/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Pipeline(steps=[('standardscaler', StandardScaler(with_mean=False)),
#                 ('linearsvc',
#                  LinearSVC(C=3, class_weight='balanced', dual=False))])

# %%
pkl_filename = '../../data/svm_v6_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_dev_svm)
target_names = list(le.classes_)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
target_names.remove('')
labels.remove(0)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.969     0.949     0.959    240418
#            !      0.233     0.279     0.254       373
#            "      0.269     0.396     0.320      2243
#           ",      0.498     0.546     0.521       848
#           ".      0.121     0.140     0.130       300
#            (      0.888     0.892     0.890      1693
#            )      0.699     0.810     0.750      1003
#           ),      0.581     0.673     0.623       385
#           ).      0.634     0.893     0.741       271
#            ,      0.621     0.666     0.643     18651
#            -      0.101     0.170     0.127       935
#            .      0.929     0.947     0.938     11435
#          ...      0.038     0.057     0.045        70
#            :      0.486     0.706     0.576       935
#           :"      0.079     0.176     0.110        68
#            ;      0.093     0.182     0.123       628
#            ?      0.586     0.607     0.597       453
#
#     accuracy                          0.916    280709
#    macro avg      0.460     0.535     0.491    280709
# weighted avg      0.926     0.916     0.920    280709
#
#               precision    recall  f1-score   support
#
#            !      0.233     0.279     0.254       373
#            "      0.269     0.396     0.320      2243
#           ",      0.498     0.546     0.521       848
#           ".      0.121     0.140     0.130       300
#            (      0.888     0.892     0.890      1693
#            )      0.699     0.810     0.750      1003
#           ),      0.581     0.673     0.623       385
#           ).      0.634     0.893     0.741       271
#            ,      0.621     0.666     0.643     18651
#            -      0.101     0.170     0.127       935
#            .      0.929     0.947     0.938     11435
#          ...      0.038     0.057     0.045        70
#            :      0.486     0.706     0.576       935
#           :"      0.079     0.176     0.110        68
#            ;      0.093     0.182     0.123       628
#            ?      0.586     0.607     0.597       453
#
#    micro avg      0.637     0.715     0.673     40291
#    macro avg      0.429     0.509     0.462     40291
# weighted avg      0.666     0.715     0.688     40291

# %% [markdown]
# #### Worse results with balanced weight

# %% [markdown]
# ### SVM - no scaling, dual=False, C=3

# %%
# %%time
clf = LinearSVC(dual=False, C=3)
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# CPU times: user 2h 16min 45s, sys: 16min 30s, total: 2h 33min 15s
# Wall time: 27min 48s
# LinearSVC(C=3, dual=False)

# %%
pkl_filename = '../../data/svm_v7_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_dev_svm)
target_names = list(le.classes_)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
target_names.remove('')
labels.remove(0)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.963     0.985     0.974    240418
#            !      0.482     0.247     0.326       373
#            "      0.514     0.218     0.306      2243
#           ",      0.693     0.553     0.615       848
#           ".      0.344     0.150     0.209       300
#            (      0.958     0.905     0.931      1693
#            )      0.878     0.831     0.853      1003
#           ),      0.777     0.688     0.730       385
#           ).      0.937     0.930     0.933       271
#            ,      0.769     0.656     0.708     18651
#            -      0.327     0.136     0.192       935
#            .      0.946     0.977     0.961     11435
#          ...      0.214     0.043     0.071        70
#            :      0.814     0.646     0.720       935
#           :"      0.727     0.118     0.203        68
#            ;      0.214     0.083     0.119       628
#            ?      0.810     0.779     0.794       453
#
#     accuracy                          0.945    280709
#    macro avg      0.669     0.526     0.567    280709
# weighted avg      0.938     0.945     0.940    280709
#
#               precision    recall  f1-score   support
#
#            !      0.482     0.247     0.326       373
#            "      0.514     0.218     0.306      2243
#           ",      0.693     0.553     0.615       848
#           ".      0.344     0.150     0.209       300
#            (      0.958     0.905     0.931      1693
#            )      0.878     0.831     0.853      1003
#           ),      0.777     0.688     0.730       385
#           ).      0.937     0.930     0.933       271
#            ,      0.769     0.656     0.708     18651
#            -      0.327     0.136     0.192       935
#            .      0.946     0.977     0.961     11435
#          ...      0.214     0.043     0.071        70
#            :      0.814     0.646     0.720       935
#           :"      0.727     0.118     0.203        68
#            ;      0.214     0.083     0.119       628
#            ?      0.810     0.779     0.794       453
#
#    micro avg      0.823     0.708     0.761     40291
#    macro avg      0.650     0.497     0.542     40291
# weighted avg      0.791     0.708     0.741     40291

# %%
actual_y_pred = le.inverse_transform(y_pred)
punctuated_sentences = scikit_punctuate(X_dev_flat, actual_y_pred)
print(punctuated_sentences[:10671])
# Out:
# но синовете им не умъртви, защото постъпи според писаното в закона в книгата на мойсей, където господ заповяда и каза: бащите да не умират заради синовете и синовете да не умират заради бащите, а всеки да умира за собствения си грях. но когато ти говоря ще отворя устата ти и ти им кажи: така казва господ бог, който слуша, нека слуша; а който не слуша, нека не слуша, защото са бунтовен дом. защото кой е по-голям, този, който седи на трапезата ли или онзи, който слугува? а след това ще се насели, както в предишните дни, заявява господ. а той беше на задната част заспал на възглавница. ефрем е като птица славата му ще отлети. и така той си отиде от него на известно разстояние. не бягам при халдейците. и израилевите синове излязоха от египетската земя, строени а когато ахитофел видя, че съветът му не се изпълни оседла магарето си и стана и отиде у дома си в своя град и нареди домашните си, работи и се обеси. ако умре някое животно от добитъка, който можете да ядете, който се допре до мършата му, ще бъде нечист до вечерта. но помощник съответен на адам, не се намери. който задържа жито, народът ще го проклина, а благословение ще почива на главата на този, който го продава. този човек беше праведен, и благочестив и чакаше, утехата на израил и светият дух беше на него. всичко е възможно за този, който вярва. и видях височината на дома околовръст основите на страничните стаи бяха една цяла тръстика от шест големи лакътя. после да вземеш тлъстината на овена, опашката и тлъстината, която покрива вътрешностите, булото на дроба, двата бъбрека с тлъстината, която е около тях и дясното бедро; защото е овен на посвещение и един хляб, една пита хляб месен с маслинено масло и една кора от коша на безквасните хлябове, които са пред господа. и от дима излязоха скакалци по земята и им се даде власт като властта, която имат земните скорпиони. ти си, господи, само ти? и ще предаде израил заради греховете на еровоам, с които съгреши и с които въведе израил в грях. синове на елифаз: теман: и омар, сефи и готом, кенез, и тамна и амалик. а гладът в самария беше страшен. затова казах в сърцето си, че и това е суета. насладих се на сянката му и седнах и плодът му, бе сладък в устата ми. защото така ми каза: господ, както ръмжи над лова си, лъвът младият лъв срещу когото се свикват множество овчари и не се плаши от гласа им, и не се отдръпва пред шума им, така господ на войнствата: ще слезе за да воюва за хълма сион и за неговото възвишение. отче, свети, опази ги в името си, което си ми дал, за да бъдат едно, както сме и ние. и да правите разлика между чистите животни и нечистите и между нечистите птици и чистите и да не осквернявате себе си с животно, или с птица или с каквото и да е, което пълзи по земята, което аз съм ви отделил като нечисто. и господ укрепи моавския цар еглон против израил, защото вършиха зло пред господа. и духът ми каза: да отида с тях, без да се двоумя. в двадесет и седмата година на израилевия цар еровоам се възцари азария, синът на юдовия цар амасия. защото вашата послушност е известна на всички, затова се радвам за вас! той изтегля всички с въдица влачи ги в мрежата си и ги събира в рибарската си мрежа, затова се радва и се весели. благословен да е господ бог, богът! на израил, който единствен върши чудеса! и които влязоха мъжко и женско от всяка плът, влязоха както бог му беше заповядал и господ затвори след него. тогава царят каза на божия човек: ела с мен у дома и се подкрепи и ще ти дам подарък. и ето, въпреки че е посадена ще успее ли? от дома тогарма, даваха за стоките ти коне бойни коне, и мулета. затова, заповядай, гробът да се пази здраво до третия ден да не би учениците му да дойдат и да го откраднат, и да кажат на народа възкръсна от мъртвите. и когато отвори петия печат, видях под олтара душите на онези, които са били заклани за божието слово и за свидетелството, което държаха. и свещениците, които служат на господа са синовете на аарон и левитите са в службата. той тича след тях с умолителни думи, но тях ги няма. и  ...

# %% [markdown]
# #### Result: Better performance without scaling.

# %%
# %%time
clf = LinearSVC(dual=False, C=4)
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# CPU times: user 2h 16min 17s, sys: 16min 42s, total: 2h 33min
# Wall time: 27min 49s
# LinearSVC(C=4, dual=False)

# %%
pkl_filename = '../../data/svm_v8_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_dev_svm)
target_names = list(le.classes_)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
target_names.remove('')
labels.remove(0)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.963     0.985     0.974    240418
#            !      0.470     0.252     0.328       373
#            "      0.498     0.221     0.306      2243
#           ",      0.688     0.553     0.613       848
#           ".      0.326     0.153     0.209       300
#            (      0.961     0.905     0.932      1693
#            )      0.876     0.833     0.854      1003
#           ),      0.776     0.694     0.733       385
#           ).      0.937     0.937     0.937       271
#            ,      0.773     0.654     0.708     18651
#            -      0.305     0.136     0.188       935
#            .      0.946     0.975     0.961     11435
#          ...      0.214     0.043     0.071        70
#            :      0.814     0.645     0.720       935
#           :"      0.615     0.118     0.198        68
#            ;      0.192     0.084     0.117       628
#            ?      0.803     0.784     0.793       453
#
#     accuracy                          0.945    280709
#    macro avg      0.656     0.528     0.567    280709
# weighted avg      0.938     0.945     0.940    280709
#
#               precision    recall  f1-score   support
#
#            !      0.470     0.252     0.328       373
#            "      0.498     0.221     0.306      2243
#           ",      0.688     0.553     0.613       848
#           ".      0.326     0.153     0.209       300
#            (      0.961     0.905     0.932      1693
#            )      0.876     0.833     0.854      1003
#           ),      0.776     0.694     0.733       385
#           ).      0.937     0.937     0.937       271
#            ,      0.773     0.654     0.708     18651
#            -      0.305     0.136     0.188       935
#            .      0.946     0.975     0.961     11435
#          ...      0.214     0.043     0.071        70
#            :      0.814     0.645     0.720       935
#           :"      0.615     0.118     0.198        68
#            ;      0.192     0.084     0.117       628
#            ?      0.803     0.784     0.793       453
#
#    micro avg      0.822     0.707     0.760     40291
#    macro avg      0.637     0.499     0.542     40291
# weighted avg      0.790     0.707     0.741     40291

# %% [markdown]
# #### Result: No improvement

# %%
# %%time
clf = LinearSVC(C=3)
clf.fit(X_train_60_svm, y_train_60_svm)
# Out:
# CPU times: user 3h 4min 19s, sys: 21.7 s, total: 3h 4min 41s
# Wall time: 3h 5min 11s
# LinearSVC(C=3)

# %%
pkl_filename = '../../data/svm_v9_model.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_dev_svm)
target_names = list(le.classes_)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
target_names.remove('')
labels.remove(0)
print(classification_report(y_dev_svm, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#                   0.964     0.984     0.974    240418
#            !      0.445     0.282     0.345       373
#            "      0.510     0.222     0.309      2243
#           ",      0.725     0.531     0.613       848
#           ".      0.350     0.143     0.203       300
#            (      0.958     0.904     0.930      1693
#            )      0.874     0.846     0.860      1003
#           ),      0.790     0.673     0.727       385
#           ).      0.931     0.941     0.936       271
#            ,      0.750     0.680     0.713     18651
#            -      0.426     0.120     0.187       935
#            .      0.947     0.975     0.961     11435
#          ...      0.222     0.057     0.091        70
#            :      0.836     0.636     0.723       935
#           :"      0.727     0.118     0.203        68
#            ;      0.264     0.038     0.067       628
#            ?      0.793     0.788     0.791       453
#
#     accuracy                          0.946    280709
#    macro avg      0.677     0.526     0.567    280709
# weighted avg      0.939     0.946     0.941    280709
#
#               precision    recall  f1-score   support
#
#            !      0.445     0.282     0.345       373
#            "      0.510     0.222     0.309      2243
#           ",      0.725     0.531     0.613       848
#           ".      0.350     0.143     0.203       300
#            (      0.958     0.904     0.930      1693
#            )      0.874     0.846     0.860      1003
#           ),      0.790     0.673     0.727       385
#           ).      0.931     0.941     0.936       271
#            ,      0.750     0.680     0.713     18651
#            -      0.426     0.120     0.187       935
#            .      0.947     0.975     0.961     11435
#          ...      0.222     0.057     0.091        70
#            :      0.836     0.636     0.723       935
#           :"      0.727     0.118     0.203        68
#            ;      0.264     0.038     0.067       628
#            ?      0.793     0.788     0.791       453
#
#    micro avg      0.818     0.718     0.765     40291
#    macro avg      0.659     0.497     0.541     40291
# weighted avg      0.786     0.718     0.743     40291

# %%
actual_y_pred = le.inverse_transform(y_pred)
punctuated_sentences = scikit_punctuate(X_dev_flat, actual_y_pred)
print(punctuated_sentences[:10671])
# Out:
# но синовете им не умъртви, защото постъпи според писаното в закона, в книгата на мойсей, където господ заповяда и каза: бащите да не умират заради синовете и синовете да не умират заради бащите, а всеки да умира за собствения си грях. но когато ти говоря, ще отворя устата ти и ти им кажи: така казва господ, бог, който слуша, нека слуша, а който не слуша, нека не слуша, защото са бунтовен дом. защото кой е по-голям този, който седи на трапезата ли или онзи, който слугува? а след това ще се насели, както в предишните дни, заявява господ. а той беше на задната част заспал на възглавница. ефрем е като птица славата му ще отлети. и така той си отиде от него на известно разстояние. не бягам при халдейците. и израилевите синове излязоха от египетската земя, строени. а когато ахитофел видя, че съветът му не се изпълни оседла магарето си и стана и отиде у дома си в своя град и нареди домашните си, работи и се обеси. ако умре някое животно от добитъка, който можете да ядете, който се допре до мършата му, ще бъде нечист до вечерта. но помощник съответен на адам, не се намери. който задържа жито, народът ще го проклина, а благословение ще почива на главата на този, който го продава. този човек беше праведен и благочестив и чакаше, утехата на израил и светият дух беше на него. всичко е възможно за този, който вярва. и видях височината на дома околовръст, основите на страничните стаи бяха една цяла тръстика от шест големи лакътя. после да вземеш тлъстината на овена, опашката и тлъстината, която покрива вътрешностите, булото на дроба, двата бъбрека с тлъстината, която е около тях и дясното бедро, защото е овен на посвещение и един хляб, една пита хляб, месен с маслинено масло и една кора от коша на безквасните хлябове, които са пред господа. и от дима излязоха скакалци по земята и им се даде власт като властта, която имат земните скорпиони. ти си, господи, само ти! и ще предаде израил заради греховете на еровоам, с които съгреши и с които въведе израил в грях. синове на елифаз: теман: и омар, сефи и готом, кенез, и тамна и амалик. а гладът в самария беше страшен. затова казах в сърцето си, че и това е суета. насладих се на сянката му и седнах и плодът му, бе сладък в устата ми. защото така ми каза: господ, както ръмжи над лова си, лъвът младият лъв срещу когото се свикват множество овчари и не, се плаши от гласа им, и не се отдръпва, пред шума им, така, господ на войнствата, ще слезе за да воюва за хълма сион и за неговото възвишение. отче, свети, опази ги в името си, което си ми дал, за да бъдат едно, както сме и ние. и да правите разлика между чистите животни и нечистите и между нечистите птици и чистите и да не осквернявате себе си с животно, или с птица или с каквото и да е, което пълзи по земята, което аз съм ви отделил като нечисто. и господ укрепи моавския цар еглон против израил, защото вършиха зло пред господа. и духът ми каза: да отида с тях, без да се двоумя. в двадесет и седмата година на израилевия цар еровоам се възцари азария, синът на юдовия цар амасия. защото вашата послушност е известна на всички затова се радвам за вас! той изтегля, всички с въдица влачи ги в мрежата си и ги събира в рибарската си мрежа, затова се радва и се весели. благословен да е господ бог, богът! на израил, който единствен върши чудеса! и които влязоха мъжко и женско от всяка плът, влязоха както бог му беше заповядал и господ, затвори след него. тогава царят каза на божия човек: ела с мен у дома и се подкрепи и ще ти дам подарък. и ето, въпреки че е посадена ще успее ли? от дома тогарма, даваха за стоките ти коне бойни коне, и мулета. затова, заповядай гробът да се пази здраво до третия ден да не би учениците му да дойдат и да го откраднат, и да кажат на народа възкръсна от мъртвите. и когато отвори петия печат, видях под олтара душите на онези, които са били заклани за божието слово и за свидетелството, което държаха. и свещениците, които служат на господа са синовете на аарон и левитите са в службата. той тича след тях с умолителни думи, но тях ги н ...

# %% [markdown]
# #### Result: Gets a little bit higher recall and a little bit lower precision - a little bit better F-score. Not that very different.
