# %% [markdown]
# ### Import Functions

# %%
from ipynb.fs.full.utilities import *
from sklearn.feature_extraction import DictVectorizer
from sklearn import preprocessing
import pickle
from sklearn.metrics import classification_report

# %% [markdown]
# ### Data Prep

# %%
X_train_60 = load_json('../../data/Train_60_X.json')
y_train_60 = load_json('../../data/Train_60_y.json')
X_test_20 = load_json('../../data/Test_20_X.json')
y_test_20 = load_json('../../data/Test_20_y.json')

# %%
verify_prepped_data(X_train_60, y_train_60)
verify_prepped_data(X_test_20, y_test_20)

# %%
X_train_60_flat = [word for sentence in X_train_60 for word in sentence]
y_train_60_flat = [label for sentence in y_train_60 for label in sentence]
X_test_20_flat = [word for sentence in X_test_20 for word in sentence]
y_test_20_flat = [label for sentence in y_test_20 for label in sentence]

# %%
print(len(X_train_60_flat) == len(y_train_60_flat))
print(len(X_test_20_flat) == len(y_test_20_flat))
# Out:
# True
# True

# %%
X_train_60[0]
# Out:
# [{'word': '^',
#   'sent_len': 6,
#   'upos': 'PART',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Te',
#   'BOS': True,
#   'next_word': 'нека',
#   'next_word_upos': 'PART',
#   'next_word_xpos_type': 'Tv',
#   'word_after_next_word': 'не',
#   'word_after_next_word_upos': 'PART',
#   'word_after_next_word_xpos_type': 'Tn',
#   'contains_publicistic_word': False},
#  {'word': 'нека',
#   'sent_len': 6,
#   'upos': 'PART',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Tv',
#   'prev_word': '^',
#   'prev_word_upos': 'PART',
#   'prev_word_xpos_type': 'Te',
#   'next_word': 'не',
#   'next_word_upos': 'PART',
#   'next_word_xpos_type': 'Tn',
#   'word_after_next_word': 'кажат',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-p',
#   'contains_publicistic_word': False},
#  {'word': 'не',
#   'sent_len': 6,
#   'upos': 'PART',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Tn',
#   'prev_word': 'нека',
#   'prev_word_upos': 'PART',
#   'prev_word_xpos_type': 'Tv',
#   'word_before_prev_word': '^',
#   'word_before_prev_word_upos': 'PART',
#   'word_before_prev_word_xpos_type': 'Te',
#   'next_word': 'кажат',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-p',
#   'word_after_next_word': 'погълнахме',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-p',
#   'contains_publicistic_word': False},
#  {'word': 'кажат',
#   'sent_len': 6,
#   'upos': 'VERB',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-p',
#   'prev_word': 'не',
#   'prev_word_upos': 'PART',
#   'prev_word_xpos_type': 'Tn',
#   'word_before_prev_word': 'нека',
#   'word_before_prev_word_upos': 'PART',
#   'word_before_prev_word_xpos_type': 'Tv',
#   'next_word': 'погълнахме',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-p',
#   'word_after_next_word': 'го',
#   'word_after_next_word_upos': 'PRON',
#   'word_after_next_word_xpos_type': 'Pp',
#   'word_after_next_word_xpos_gender_number_article': 'ms',
#   'word_after_next_word_xpos_ref_type': 'e',
#   'contains_publicistic_word': False},
#  {'word': 'погълнахме',
#   'sent_len': 6,
#   'upos': 'VERB',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-p',
#   'prev_word': 'кажат',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-p',
#   'word_before_prev_word': 'не',
#   'word_before_prev_word_upos': 'PART',
#   'word_before_prev_word_xpos_type': 'Tn',
#   'next_word': 'го',
#   'next_word_upos': 'PRON',
#   'next_word_xpos_type': 'Pp',
#   'next_word_xpos_gender_number_article': 'ms',
#   'next_word_xpos_ref_type': 'e',
#   'contains_publicistic_word': False},
#  {'word': 'го',
#   'sent_len': 6,
#   'upos': 'PRON',
#   'first_word_in_sent': 'нека',
#   'contains_interrogative_word': False,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'word_xpos_type': 'Pp',
#   'word_xpos_gender_number_article': 'ms',
#   'word_xpos_ref_type': 'e',
#   'prev_word': 'погълнахме',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-p',
#   'word_before_prev_word': 'кажат',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-p',
#   'EOS': True,
#   'contains_publicistic_word': False}]

# %%
X_test_20[0]
# Out:
# [{'word': '^',
#   'sent_len': 20,
#   'upos': 'PART',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'punct',
#   'BOS': True,
#   'next_word': 'защото',
#   'next_word_upos': 'ADV',
#   'next_word_xpos_type': 'Pr',
#   'next_word_xpos_gender_number_article': '',
#   'word_after_next_word': 'ако',
#   'word_after_next_word_upos': 'SCONJ',
#   'word_after_next_word_xpos_type': 'Cs'},
#  {'word': 'защото',
#   'sent_len': 20,
#   'upos': 'ADV',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Pr',
#   'word_xpos_gender_number_article': '',
#   'prev_word': '^',
#   'prev_word_upos': 'PART',
#   'prev_word_xpos_type': 'punct',
#   'next_word': 'ако',
#   'next_word_upos': 'SCONJ',
#   'next_word_xpos_type': 'Cs',
#   'word_after_next_word': 'авраам',
#   'word_after_next_word_upos': 'PROPN',
#   'word_after_next_word_xpos_type': 'Np',
#   'word_after_next_word_xpos_gender_number_article': 'msi'},
#  {'word': 'ако',
#   'sent_len': 20,
#   'upos': 'SCONJ',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Cs',
#   'prev_word': 'защото',
#   'prev_word_upos': 'ADV',
#   'prev_word_xpos_type': 'Pr',
#   'prev_word_xpos_gender_number_article': '',
#   'word_before_prev_word': '^',
#   'word_before_prev_word_upos': 'PART',
#   'word_before_prev_word_xpos_type': 'punct',
#   'next_word': 'авраам',
#   'next_word_upos': 'PROPN',
#   'next_word_xpos_type': 'Np',
#   'next_word_xpos_gender_number_article': 'msi',
#   'word_after_next_word': 'е',
#   'word_after_next_word_upos': 'AUX',
#   'word_after_next_word_xpos_type': 'Vx',
#   'word_after_next_word_xpos_gender_number_article': '-s'},
#  {'word': 'авраам',
#   'sent_len': 20,
#   'upos': 'PROPN',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Np',
#   'word_xpos_gender_number_article': 'msi',
#   'prev_word': 'ако',
#   'prev_word_upos': 'SCONJ',
#   'prev_word_xpos_type': 'Cs',
#   'word_before_prev_word': 'защото',
#   'word_before_prev_word_upos': 'ADV',
#   'word_before_prev_word_xpos_type': 'Pr',
#   'word_before_prev_word_xpos_gender_number_article': '',
#   'next_word': 'е',
#   'next_word_upos': 'AUX',
#   'next_word_xpos_type': 'Vx',
#   'next_word_xpos_gender_number_article': '-s',
#   'word_after_next_word': 'бил',
#   'word_after_next_word_upos': 'AUX',
#   'word_after_next_word_xpos_type': 'Vx',
#   'word_after_next_word_xpos_gender_number_article': 'msi',
#   'word_after_next_word_xpos_mood': 'c'},
#  {'word': 'е',
#   'sent_len': 20,
#   'upos': 'AUX',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Vx',
#   'word_xpos_gender_number_article': '-s',
#   'prev_word': 'авраам',
#   'prev_word_upos': 'PROPN',
#   'prev_word_xpos_type': 'Np',
#   'prev_word_xpos_gender_number_article': 'msi',
#   'word_before_prev_word': 'ако',
#   'word_before_prev_word_upos': 'SCONJ',
#   'word_before_prev_word_xpos_type': 'Cs',
#   'next_word': 'бил',
#   'next_word_upos': 'AUX',
#   'next_word_xpos_type': 'Vx',
#   'next_word_xpos_gender_number_article': 'msi',
#   'next_word_xpos_mood': 'c',
#   'word_after_next_word': 'оправдан',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': 'msi',
#   'word_after_next_word_xpos_mood': 'c'},
#  {'word': 'бил',
#   'sent_len': 20,
#   'upos': 'AUX',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Vx',
#   'word_xpos_gender_number_article': 'msi',
#   'word_xpos_mood': 'c',
#   'prev_word': 'е',
#   'prev_word_upos': 'AUX',
#   'prev_word_xpos_type': 'Vx',
#   'prev_word_xpos_gender_number_article': '-s',
#   'word_before_prev_word': 'авраам',
#   'word_before_prev_word_upos': 'PROPN',
#   'word_before_prev_word_xpos_type': 'Np',
#   'word_before_prev_word_xpos_gender_number_article': 'msi',
#   'next_word': 'оправдан',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': 'msi',
#   'next_word_xpos_mood': 'c',
#   'word_after_next_word': 'чрез',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R'},
#  {'word': 'оправдан',
#   'sent_len': 20,
#   'upos': 'VERB',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': 'msi',
#   'word_xpos_mood': 'c',
#   'prev_word': 'бил',
#   'prev_word_upos': 'AUX',
#   'prev_word_xpos_type': 'Vx',
#   'prev_word_xpos_gender_number_article': 'msi',
#   'prev_word_xpos_mood': 'c',
#   'word_before_prev_word': 'е',
#   'word_before_prev_word_upos': 'AUX',
#   'word_before_prev_word_xpos_type': 'Vx',
#   'word_before_prev_word_xpos_gender_number_article': '-s',
#   'next_word': 'чрез',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'дела',
#   'word_after_next_word_upos': 'NOUN',
#   'word_after_next_word_xpos_type': 'Nc',
#   'word_after_next_word_xpos_gender_number_article': 'npi'},
#  {'word': 'чрез',
#   'sent_len': 20,
#   'upos': 'ADP',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'R',
#   'prev_word': 'оправдан',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': 'msi',
#   'prev_word_xpos_mood': 'c',
#   'word_before_prev_word': 'бил',
#   'word_before_prev_word_upos': 'AUX',
#   'word_before_prev_word_xpos_type': 'Vx',
#   'word_before_prev_word_xpos_gender_number_article': 'msi',
#   'word_before_prev_word_xpos_mood': 'c',
#   'next_word': 'дела',
#   'next_word_upos': 'NOUN',
#   'next_word_xpos_type': 'Nc',
#   'next_word_xpos_gender_number_article': 'npi',
#   'word_after_next_word': 'той',
#   'word_after_next_word_upos': 'PRON',
#   'word_after_next_word_xpos_type': 'Pp',
#   'word_after_next_word_xpos_gender_number_article': 'ms',
#   'word_after_next_word_xpos_ref_type': 'e'},
#  {'word': 'дела',
#   'sent_len': 20,
#   'upos': 'NOUN',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Nc',
#   'word_xpos_gender_number_article': 'npi',
#   'prev_word': 'чрез',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'оправдан',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': 'msi',
#   'word_before_prev_word_xpos_mood': 'c',
#   'next_word': 'той',
#   'next_word_upos': 'PRON',
#   'next_word_xpos_type': 'Pp',
#   'next_word_xpos_gender_number_article': 'ms',
#   'next_word_xpos_ref_type': 'e',
#   'word_after_next_word': 'има',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-s'},
#  {'word': 'той',
#   'sent_len': 20,
#   'upos': 'PRON',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Pp',
#   'word_xpos_gender_number_article': 'ms',
#   'word_xpos_ref_type': 'e',
#   'prev_word': 'дела',
#   'prev_word_upos': 'NOUN',
#   'prev_word_xpos_type': 'Nc',
#   'prev_word_xpos_gender_number_article': 'npi',
#   'word_before_prev_word': 'чрез',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'има',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-s',
#   'word_after_next_word': 'с',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R'},
#  {'word': 'има',
#   'sent_len': 20,
#   'upos': 'VERB',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-s',
#   'prev_word': 'той',
#   'prev_word_upos': 'PRON',
#   'prev_word_xpos_type': 'Pp',
#   'prev_word_xpos_gender_number_article': 'ms',
#   'prev_word_xpos_ref_type': 'e',
#   'word_before_prev_word': 'дела',
#   'word_before_prev_word_upos': 'NOUN',
#   'word_before_prev_word_xpos_type': 'Nc',
#   'word_before_prev_word_xpos_gender_number_article': 'npi',
#   'next_word': 'с',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'какво',
#   'word_after_next_word_upos': 'DET',
#   'word_after_next_word_xpos_type': 'Pi',
#   'word_after_next_word_xpos_gender_number_article': 'ns',
#   'word_after_next_word_xpos_ref_type': 'a'},
#  {'word': 'с',
#   'sent_len': 20,
#   'upos': 'ADP',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'R',
#   'prev_word': 'има',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-s',
#   'word_before_prev_word': 'той',
#   'word_before_prev_word_upos': 'PRON',
#   'word_before_prev_word_xpos_type': 'Pp',
#   'word_before_prev_word_xpos_gender_number_article': 'ms',
#   'word_before_prev_word_xpos_ref_type': 'e',
#   'next_word': 'какво',
#   'next_word_upos': 'DET',
#   'next_word_xpos_type': 'Pi',
#   'next_word_xpos_gender_number_article': 'ns',
#   'next_word_xpos_ref_type': 'a',
#   'word_after_next_word': 'да',
#   'word_after_next_word_upos': 'AUX',
#   'word_after_next_word_xpos_type': 'Tx'},
#  {'word': 'какво',
#   'sent_len': 20,
#   'upos': 'DET',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Pi',
#   'word_xpos_gender_number_article': 'ns',
#   'word_xpos_ref_type': 'a',
#   'prev_word': 'с',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'има',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-s',
#   'next_word': 'да',
#   'next_word_upos': 'AUX',
#   'next_word_xpos_type': 'Tx',
#   'word_after_next_word': 'се',
#   'word_after_next_word_upos': 'PRON',
#   'word_after_next_word_xpos_type': 'Pp',
#   'word_after_next_word_xpos_gender_number_article': ''},
#  {'word': 'да',
#   'sent_len': 20,
#   'upos': 'AUX',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Tx',
#   'prev_word': 'какво',
#   'prev_word_upos': 'DET',
#   'prev_word_xpos_type': 'Pi',
#   'prev_word_xpos_gender_number_article': 'ns',
#   'prev_word_xpos_ref_type': 'a',
#   'word_before_prev_word': 'с',
#   'word_before_prev_word_upos': 'ADP',
#   'word_before_prev_word_xpos_type': 'R',
#   'next_word': 'се',
#   'next_word_upos': 'PRON',
#   'next_word_xpos_type': 'Pp',
#   'next_word_xpos_gender_number_article': '',
#   'word_after_next_word': 'хвали',
#   'word_after_next_word_upos': 'VERB',
#   'word_after_next_word_xpos_type': 'Vp',
#   'word_after_next_word_xpos_gender_number_article': '-s'},
#  {'word': 'се',
#   'sent_len': 20,
#   'upos': 'PRON',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': True,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Pp',
#   'word_xpos_gender_number_article': '',
#   'prev_word': 'да',
#   'prev_word_upos': 'AUX',
#   'prev_word_xpos_type': 'Tx',
#   'word_before_prev_word': 'какво',
#   'word_before_prev_word_upos': 'DET',
#   'word_before_prev_word_xpos_type': 'Pi',
#   'word_before_prev_word_xpos_gender_number_article': 'ns',
#   'word_before_prev_word_xpos_ref_type': 'a',
#   'next_word': 'хвали',
#   'next_word_upos': 'VERB',
#   'next_word_xpos_type': 'Vp',
#   'next_word_xpos_gender_number_article': '-s',
#   'word_after_next_word': 'но',
#   'word_after_next_word_upos': 'CCONJ',
#   'word_after_next_word_xpos_type': 'Cc'},
#  {'word': 'хвали',
#   'sent_len': 20,
#   'upos': 'VERB',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Vp',
#   'word_xpos_gender_number_article': '-s',
#   'prev_word': 'се',
#   'prev_word_upos': 'PRON',
#   'prev_word_xpos_type': 'Pp',
#   'prev_word_xpos_gender_number_article': '',
#   'word_before_prev_word': 'да',
#   'word_before_prev_word_upos': 'AUX',
#   'word_before_prev_word_xpos_type': 'Tx',
#   'next_word': 'но',
#   'next_word_upos': 'CCONJ',
#   'next_word_xpos_type': 'Cc',
#   'word_after_next_word': 'не',
#   'word_after_next_word_upos': 'INTJ',
#   'word_after_next_word_xpos_type': 'Tn'},
#  {'word': 'но',
#   'sent_len': 20,
#   'upos': 'CCONJ',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Cc',
#   'prev_word': 'хвали',
#   'prev_word_upos': 'VERB',
#   'prev_word_xpos_type': 'Vp',
#   'prev_word_xpos_gender_number_article': '-s',
#   'word_before_prev_word': 'се',
#   'word_before_prev_word_upos': 'PRON',
#   'word_before_prev_word_xpos_type': 'Pp',
#   'word_before_prev_word_xpos_gender_number_article': '',
#   'next_word': 'не',
#   'next_word_upos': 'INTJ',
#   'next_word_xpos_type': 'Tn',
#   'word_after_next_word': 'пред',
#   'word_after_next_word_upos': 'ADP',
#   'word_after_next_word_xpos_type': 'R'},
#  {'word': 'не',
#   'sent_len': 20,
#   'upos': 'INTJ',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Tn',
#   'prev_word': 'но',
#   'prev_word_upos': 'CCONJ',
#   'prev_word_xpos_type': 'Cc',
#   'word_before_prev_word': 'хвали',
#   'word_before_prev_word_upos': 'VERB',
#   'word_before_prev_word_xpos_type': 'Vp',
#   'word_before_prev_word_xpos_gender_number_article': '-s',
#   'next_word': 'пред',
#   'next_word_upos': 'ADP',
#   'next_word_xpos_type': 'R',
#   'word_after_next_word': 'бога',
#   'word_after_next_word_upos': 'PROPN',
#   'word_after_next_word_xpos_type': 'Np',
#   'word_after_next_word_xpos_gender_number_article': 'msh'},
#  {'word': 'пред',
#   'sent_len': 20,
#   'upos': 'ADP',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'R',
#   'prev_word': 'не',
#   'prev_word_upos': 'INTJ',
#   'prev_word_xpos_type': 'Tn',
#   'word_before_prev_word': 'но',
#   'word_before_prev_word_upos': 'CCONJ',
#   'word_before_prev_word_xpos_type': 'Cc',
#   'next_word': 'бога',
#   'next_word_upos': 'PROPN',
#   'next_word_xpos_type': 'Np',
#   'next_word_xpos_gender_number_article': 'msh'},
#  {'word': 'бога',
#   'sent_len': 20,
#   'upos': 'PROPN',
#   'first_word_in_sent': 'защото',
#   'contains_interrogative_word': True,
#   'contains_interrogative_particle': False,
#   'contains_imperative_verb': False,
#   'contains_repetitive_conj_before': False,
#   'between_two_verbs': False,
#   'contains_publicistic_word': False,
#   'word_xpos_type': 'Np',
#   'word_xpos_gender_number_article': 'msh',
#   'prev_word': 'пред',
#   'prev_word_upos': 'ADP',
#   'prev_word_xpos_type': 'R',
#   'word_before_prev_word': 'не',
#   'word_before_prev_word_upos': 'INTJ',
#   'word_before_prev_word_xpos_type': 'Tn',
#   'EOS': True}]

# %%
v = DictVectorizer()
X_train_60_lr = v.fit_transform(X_train_60_flat)
X_test_20_lr = v.transform(X_test_20_flat)

# %%
le = preprocessing.LabelEncoder()
y_train_60_lr = le.fit_transform(y_train_60_flat)
y_test_20_lr = le.transform(y_test_20_flat)

# %% [markdown]
# ### Estimate Pretrained Model on Test Set

# %%
pkl_filename = '../../models/logreg_v3_model.pkl'
with open(pkl_filename, 'rb') as file:
    clf = pickle.load(file)

# %%
labels = list(clf.classes_)
y_pred = clf.predict(X_test_20_lr)
target_names = list(le.classes_)
target_names.remove('')
labels.remove(0)
print(classification_report(y_test_20_lr, y_pred, labels=labels, target_names=target_names, digits=3))
# Out:
# /Users/mter0707/opt/anaconda3/envs/masters/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            !      0.470     0.127     0.200       747
#            "      0.629     0.057     0.105      4380
#           ",      0.704     0.519     0.598      1587
#           ".      0.485     0.023     0.043       708
#            (      0.936     0.888     0.912      3443
#            )      0.832     0.834     0.833      2038
#           ),      0.832     0.571     0.677       797
#           ).      0.892     0.839     0.865       553
#            ,      0.820     0.624     0.709     37483
#            -      0.628     0.067     0.121      2047
#            .      0.929     0.984     0.956     22826
#          ...      0.000     0.000     0.000       139
#            :      0.859     0.540     0.663      2018
#           :"      0.600     0.026     0.050       116
#            ;      0.443     0.057     0.101      1344
#            ?      0.782     0.734     0.757       872
#
#    micro avg      0.863     0.674     0.757     81098
#    macro avg      0.678     0.431     0.474     81098
# weighted avg      0.826     0.674     0.718     81098

# %%
actual_y_pred = le.inverse_transform(y_pred[:10000])
punctuated_sentences = scikit_punctuate(X_test_20_flat[:10000], actual_y_pred)
print(punctuated_sentences)
# Out:
# защото, ако авраам е бил оправдан чрез дела, той има с какво да се хвали, но не пред бога. аз иисус изпратих ангела си да ви засвидетелства това за църквите. да направиш петдесет петлици на едната завеса и петдесет петлици да направиш по края на завесата, която е във второто съединение, петлиците да са един срещу друг. тогава един от дванадесетте наречен юда искариотски отиде при главните свещеници и каза: какво ще ми дадете и аз ще ви го предам? но аз съм сред вас, като онзи, който слугува. и господ каза: ще ви предадат. само добитъка взехме за себе си като плячка и заграбеното от градовете, които превзехме. но ако някой ходи нощем се препъва, защото светлината не е в него. при реките на вавилон там седяхме и плачехме, когато си спомняхме сион. дечица да не любим с думи, нито с език, а с дело и истина. елате нощувайте във вретище служители на моя бог, защото хлебният принос и възлиянията са задържани от дома на вашия бог. и всичките дни на матусал станаха деветстотин шестдесет и девет години и умря. и ти да отговориш и да кажеш пред господа, своя бог, баща ми беше скитащ арамеец и слезе в египет, и живя там с малко хора, но там стана голям силен и многоброен народ. с вяра изпълни пасхата и поръсването с кръвта за да не се допре до тях този, който погубваше първородните. затова, нека господ ти отплати с добро за това, което ми направи днес. не никак не ги досрамя и не знаят да се изчервят. с вяра авраам, когато беше повикан да излезе и да отиде на едно място, което щеше да получи в наследство послуша и излезе, без да знае къде отива. и да напишеш на камъните всичките думи на този закон добре врязани. и им казах: какво е това високо място на което отивате? нямат разум онези, които издигат дървените си идоли и се молят на бог, който не може да спаси. сляпо животно или със строшена или изкълчена част, или което има отток или суха краста, или лишеи, да не принасяте на господа и от такива да не давате на господа жертва чрез огън на олтара. а от моя страна, ето, моя завет с тях, казва господ духът ми, който е на теб и словата ми, които сложих в устата ти няма да отстъпят от устата ти, нито от устата на потомството ти, нито от устата на потомството на потомството ти, казва господ отсега и до века. а в последните дни, хълмът на дома господен, ще се утвърди по-високо от всичките хълмове и ще се издигне над високите места и народите, ще се стичат на него. тогава казаха: елате, нека скроим замисли против еремия, защото няма да се изгуби закон от свещеник и съвет от мъдър и слово от пророк. остави ме, защото дните ми са суета. така нивата и пещерата в нея се утвърдиха на авраам от хетейците като собственост за гроб. и пратениците дойдоха пак и казаха: така говори венадад, и казва: наистина, аз изпратих до теб да кажат да ми дадеш среброто си и златото си и жените си и синовете си, но утре около това време аз ще изпратя слугите си при теб; и те ще претърсят къщата ти и къщите на слугите ти и всичко, което ти се вижда желателно ще го вземат в ръцете си и ще го отнесат. ераст остана в коринт, а трофим оставих болен в милит. да не обираш повторно лозето си и да не събираш изпадалите в лозето, зърна да ги оставиш на сиромаха и на чужденеца. а всеизгарянето, което князът да принася на господа в съботния ден да бъде шест агнета, без недостатък и един овен без недостатък. и дошлите от плена, завърналите се от плен принесоха всеизгаряния на израилевия бог дванадесет юнеца за целия израил, деветдесет и шест овена, седемдесет и седем агнета и дванадесет козела в принос за грях всичко във всеизгаряне на господа. и когато господ те въведе в земята на ханаанците, хетейците, аморейците, евейците и евусейците, за която се закле на бащите ти, че ще ти я даде земя, където текат мляко и мед, тогава да извършваш тази служба в този месец. и юдейските старейшини строяха и успяваха чрез пророкуването на пророк агей и на захария, сина на идо. боже, недей мълча не замлъквай не бъди безмълвен, боже. той се привърза към господа и не престана да го следва и пазеше з ...
